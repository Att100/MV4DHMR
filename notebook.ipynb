# %%
import pickle
import numpy as np
import json
import os
import smplx 
import torch

# %%
with open("output/shelf_600_700/smplx/sequence_smplx.pkl", "rb") as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['tracking', 'inverse_index', 'smplx_type'])

# %%
data['inverse_index'][:5]
# Out:
# [[(2, 0), (1, 0)],
#  [(2, 1), (1, 1)],
#  [(2, 2), (1, 2)],
#  [(2, 3), (1, 3)],
#  [(2, 4), (1, 4)]]
